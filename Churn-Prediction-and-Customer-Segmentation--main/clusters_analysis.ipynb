# %%
import pandas as pd

# %%
df = pd.read_csv("./Multivariate-Exploratory-Analysis-master/kmeans_test.csv")
df
# Out:
#         Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0      Hargrave          619    France  Female   42       2       0.00
# 1          Hill          608     Spain  Female   41       1   83807.86
# 2          Onio          502    France  Female   42       8  159660.80
# 3          Boni          699    France  Female   39       1       0.00
# 4      Mitchell          850     Spain  Female   43       2  125510.82
# ...         ...          ...       ...     ...  ...     ...        ...
# 9995   Obijiaku          771    France    Male   39       5       0.00
# 9996  Johnstone          516    France    Male   35      10   57369.61
# 9997        Liu          709    France  Female   36       7       0.00
# 9998  Sabbatini          772   Germany    Male   42       3   75075.31
# 9999     Walker          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
df[(df.cluster == 0)].describe()
# Out:
#        CreditScore          Age       Tenure        Balance  NumOfProducts  \
# count  4196.000000  4196.000000  4196.000000    4196.000000    4196.000000
# mean    649.278599    38.660629     5.079123   12223.712262       1.868684
# std      96.283133    10.525691     2.862262   32205.531737       0.562356
# min     350.000000    18.000000     0.000000       0.000000       1.000000
# 25%     583.000000    31.750000     3.000000       0.000000       2.000000
# 50%     650.500000    37.000000     5.000000       0.000000       2.000000
# 75%     716.000000    43.000000     8.000000       0.000000       2.000000
# max     850.000000    88.000000    10.000000  195238.290000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary       Exited  \
# count  4196.000000     4196.000000      4196.000000  4196.000000
# mean      0.709485        0.515014     99568.719178     0.175167
# std       0.454054        0.499834     57701.929507     0.380155
# ...

# %%
df[(df.cluster == 1)].describe()
# Out:
#        CreditScore          Age       Tenure        Balance  NumOfProducts  \
# count  5804.000000  5804.000000  5804.000000    5804.000000    5804.000000
# mean    651.432633    39.110613     4.964852  122944.210239       1.285493
# std      96.918271    10.457178     2.912913   28532.676846       0.460004
# min     350.000000    18.000000     0.000000   27288.430000       1.000000
# 25%     585.000000    32.000000     2.000000  104329.515000       1.000000
# 50%     653.000000    37.000000     5.000000  122299.910000       1.000000
# 75%     718.000000    44.000000     7.000000  141296.752500       2.000000
# max     850.000000    92.000000    10.000000  250898.090000       3.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary       Exited  \
# count  5804.000000     5804.000000      5804.000000  5804.000000
# mean      0.702619        0.515162    100467.273112     0.224328
# std       0.457145        0.499813     57373.719205     0.417175
# ...

# %%
cluster_num = 1
(len(df[(df.cluster == cluster_num) & (df.Exited == 1)]))/len(df[(df.cluster == cluster_num)])
# Out:
# 0.22432804962095107

# %%
# Cluster 0
0.2393878140340745

# Cluster 1
0.13548387096774195

# Cluster 2
0.241852487135506

# Cluster 3
0.14393939393939395
# Out:
# 0.168141592920354

# %%
705/2210
# Out:
# 0.3190045248868778

# %%
829/26
