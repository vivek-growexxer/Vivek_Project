# %%
import os
import numpy as np
import pandas as pd

# %%
# columns_max = ['train_accuracy', 'test_accuracy', 'roc_auc',
#            'precision_0', 'recall_0', 'f1_0', 
#            'precision_1', 'recall_1', 'f1_1',
#            'ks_stat','tp', 'tn']

# columns_max = ['train_accuracy', 'test_accuracy', 'roc_auc', 
#                'f1_0', 'f1_1', 'ks_stat','tp', 'tn']

columns_max = ['ks_stat']

columns_min = ['fn']
top_n = 1000

columns_name = ['method','k_neighbour', 'train_accuracy', 'test_accuracy', 'roc_auc',
                'precision_0', 'recall_0', 'f1_0', 
                'precision_1', 'recall_1', 'f1_1',
                'ks_stat', 'p_value', 
                'tp', 'tn', 'fp', 'fn']

root_dir = "/home/growlt200/Downloads/aws_reports/bos_eval_temp/"

# %%
def best_k_value(file_loc, top_n):
    df = pd.read_csv(file_loc)
    all_col_top_rows = {}
    
    for col in columns_max:
        top_rows = df.sort_values(by=[col],ascending=False)[:top_n]['k_neighbour']
        all_col_top_rows[col + '_top_rows'] = set(top_rows)

    for col in columns_min:
        top_rows = df.sort_values(by=[col],ascending=True)[:top_n]['k_neighbour']
        all_col_top_rows[col + '_top_rows'] = set(top_rows)

    # Finding rows which are common in all the top_rows
    common_rows = set()
    for key,value in all_col_top_rows.items():
        if len(common_rows) == 0:
            common_rows = value
        else:
            common_rows = common_rows.intersection(value)
    #     break
    
    top_rows = df[df['k_neighbour'].isin(common_rows)]
    
#     # Sorting using ks_stat
#     top_ks_stat = df.sort_values(by=['ks_stat'],ascending=False)[:top_n]['k_neighbour']
    
#     # Sorting using fn
#     top_fn = df.sort_values(by=['fn'],ascending=True)[:top_n]['k_neighbour']
    
#     # Sorting using fp
#     top_fp = df.sort_values(by=['fp'],ascending=True)[:top_n]['k_neighbour']
    
#     best_k = set(top_ks_stat).intersection(set(top_fn)).intersection(set(top_fp))
    
#     best_rows = df[df['k_neighbour'].isin(best_k)]
    
    return top_rows.sort_values(by=[columns_min[0]],ascending=True)

# %%
    if file.find('_num_data') != -1:
    if file.find('_num_cat_data') != -1:
    if file.find('_cat_as_cat_') != -1:

# %%
df = pd.DataFrame([], columns=columns_name)
best_rows_values = {}
for file in sorted(os.listdir(root_dir)):

    if file.find('_num_cat_data') != -1:
        approach = file.split('_')[1]
        method_name = file.split('_')[2].upper()

        best_rows = best_k_value(os.path.join(root_dir, file),top_n)
        print(file, len(best_rows))

        best_rows_values[method_name] = list(best_rows['k_neighbour'].values)

        best_rows.insert(0,'method' ,[f'Approach_{approach}_{method_name}']* len(best_rows) )

        df = pd.concat([df, best_rows[:1]])
#     print(best_rows[:1].values)

#     break
# Out:
# bos_ada_boost_eval_num_cat_data.csv 1186
# bos_balanced_bagging_classifier_eval_num_cat_data.csv 1304
# bos_balanced_random_forest_classifier_eval_num_cat_data.csv 1239
# bos_catboost_classifier_eval_num_cat_data.csv 1154
# bos_easy_ensemble_classifier_eval_num_cat_data.csv 1175
# bos_extra_trees_classifier_eval_num_cat_data.csv 1180
# bos_gaussian_naive_bayes_eval_num_cat_data.csv 1449
# bos_gradient_boosting_classifier_eval_num_cat_data.csv 1327
# bos_lgbm_classifier_eval_num_cat_data.csv 1216
# bos_logistic_regression_eval_num_cat_data.csv 1311
# bos_random_forest_classifier_eval_num_cat_data.csv 1263
# bos_support_vector_classifier_eval_num_cat_data.csv 1430

# %%
# np.save('./final_results/class_imbalance_methods_evaluations/best_neighbour_values.npy', best_rows_values)

# %%
df
# Out:
#                             method k_neighbour  train_accuracy  test_accuracy  \
# 701             Approach_ada_BOOST         375        0.829042         0.8020
# 2371     Approach_balanced_BAGGING         200        0.989708         0.8050
# 235       Approach_balanced_RANDOM         254        1.000000         0.8100
# 2206  Approach_catboost_CLASSIFIER         300        0.975675         0.7120
# 701         Approach_easy_ENSEMBLE         375        0.829042         0.8020
# 2206          Approach_extra_TREES         300        1.000000         0.7080
# 285        Approach_gaussian_NAIVE         187        0.720954         0.6795
# 471     Approach_gradient_BOOSTING         414        0.851823         0.8045
# 733       Approach_lgbm_CLASSIFIER         907        0.899529         0.8220
# 1997  Approach_logistic_REGRESSION        1393        0.742004         0.4890
# 2187        Approach_random_FOREST         397        1.000000         0.7375
# 0          Approach_support_VECTOR         273        0.574333         0.4595
#
#        roc_auc  precision_0  recall_0      f1_0  precision_1  recall_1  \
# 701   0.773268     0.921182  0.821720  0.868613     0.509499  0.724816
# 2371  0.744968     0.902880  0.846202  0.873623     0.516765  0.643735
# 235   0.758168     0.909521  0.845574  0.876383     0.526012  0.670762
# 2206  0.704881     0.901342  0.716886  0.798601     0.384720  0.692875
# 701   0.773268     0.921182  0.821720  0.868613     0.509499  0.724816
# 2206  0.712430     0.907842  0.704959  0.793640     0.384010  0.719902
# 285   0.698198     0.906143  0.666667  0.768174     0.358696  0.729730
# 471   0.768435     0.917361  0.829253  0.871085     0.514286  0.707617
# 733   0.774847     0.916498  0.854363  0.884340     0.549515  0.695332
# 1997  0.596905     0.880160  0.414940  0.563993     0.253803  0.778870
# 2187  0.722717     0.906393  0.747646  0.819401     0.413994  0.697789
# 0     0.562838     0.852617  0.388575  0.533851     0.235479  0.737101
#
#           f1_1   ks_stat   p_value   tp    tn   fp   fn  \
# 701   0.598377  0.548993  0.000000  295  1309  284  112
# 2371  0.573304  0.503491  0.000000  262  1348  245  145
# 235   0.589633  0.531842  0.000000  273  1347  246  134
# 2206  0.494737  0.414155  0.000000  282  1142  451  125
# 701   0.598377  0.548993  0.000000  295  1309  284  112
# 2206  0.500855  0.426366  0.000000  293  1123  470  114
# 285   0.480972  0.401189  0.000000  297  1062  531  110
# 471   0.595657  0.550248  0.000000  288  1321  272  119
# 733   0.613883  0.550322  0.000000  283  1361  232  124
# 1997  0.382850  0.244022  0.000000  317   661  932   90
# 2187  0.519671  0.445435  0.000000  284  1191  402  123
# 0     0.356930  0.129280  0.000035  300   619  974  107
#
#                                   model   sampling_method
# 701                           ada_boost  borderline_smote
# 2371        balanced_bagging_classifier        smotetomek
# 235   balanced_random_forest_classifier             smote
# 2206                catboost_classifier          smoteenn
# 701            easy_ensemble_classifier  borderline_smote
# 2206             extra_trees_classifier          smoteenn
# 285                gaussian_naive_bayes            adasyn
# 471        gradient_boosting_classifier            adasyn
# 733                     lgbm_classifier  borderline_smote
# 1997                logistic_regression          smoteenn
# 2187           random_forest_classifier          smoteenn
# 0             support_vector_classifier             smote

# %%
df[df.ks_stat>0.45].sort_values(by=['ks_stat'], ascending=False)
# Out:
#                           method k_neighbour  train_accuracy  test_accuracy  \
# 733     Approach_lgbm_CLASSIFIER         907        0.899529         0.8220
# 471   Approach_gradient_BOOSTING         414        0.851823         0.8045
# 701           Approach_ada_BOOST         375        0.829042         0.8020
# 701       Approach_easy_ENSEMBLE         375        0.829042         0.8020
# 235     Approach_balanced_RANDOM         254        1.000000         0.8100
# 2371   Approach_balanced_BAGGING         200        0.989708         0.8050
#
#        roc_auc  precision_0  recall_0      f1_0  precision_1  recall_1  \
# 733   0.774847     0.916498  0.854363  0.884340     0.549515  0.695332
# 471   0.768435     0.917361  0.829253  0.871085     0.514286  0.707617
# 701   0.773268     0.921182  0.821720  0.868613     0.509499  0.724816
# 701   0.773268     0.921182  0.821720  0.868613     0.509499  0.724816
# 235   0.758168     0.909521  0.845574  0.876383     0.526012  0.670762
# 2371  0.744968     0.902880  0.846202  0.873623     0.516765  0.643735
#
#           f1_1   ks_stat  p_value   tp    tn   fp   fn  \
# 733   0.613883  0.550322      0.0  283  1361  232  124
# 471   0.595657  0.550248      0.0  288  1321  272  119
# 701   0.598377  0.548993      0.0  295  1309  284  112
# 701   0.598377  0.548993      0.0  295  1309  284  112
# 235   0.589633  0.531842      0.0  273  1347  246  134
# 2371  0.573304  0.503491      0.0  262  1348  245  145
#
#                                   model   sampling_method
# 733                     lgbm_classifier  borderline_smote
# 471        gradient_boosting_classifier            adasyn
# 701                           ada_boost  borderline_smote
# 701            easy_ensemble_classifier  borderline_smote
# 235   balanced_random_forest_classifier             smote
# 2371        balanced_bagging_classifier        smotetomek

# %%
df[df.ks_stat>0.45].sort_values(by=['ks_stat'], ascending=False).to_csv(
    './final_results/potential_models/fn_num_cat.csv', 
    header=True, 
    index=False
)

# %%
df.sort_values(by=['ks_stat'], ascending=False)[:5]
# Out:
#                             method k_neighbour  train_accuracy  test_accuracy  \
# 1442    Approach_gradient_BOOSTING        1173        0.918524         0.8690
# 1423      Approach_lgbm_CLASSIFIER        1208        0.946546         0.8615
# 1407  Approach_catboost_CLASSIFIER         818        0.950471         0.8695
# 1412            Approach_ada_BOOST         950        0.909890         0.8550
# 1395        Approach_easy_ENSEMBLE         844        0.909341         0.8570
#
#        roc_auc  precision_0  recall_0      f1_0  precision_1  recall_1  \
# 1442  0.724779     0.879635  0.967985  0.921698     0.793522  0.481572
# 1423  0.716412     0.876861  0.961080  0.917041     0.755906  0.471744
# 1407  0.726922     0.880571  0.967357  0.921926     0.792000  0.486486
# 1412  0.707759     0.873781  0.956058  0.913070     0.727626  0.459459
# 1395  0.712673     0.875791  0.956058  0.914166     0.731801  0.469287
#
#           f1_1   ks_stat  p_value   tp    tn  fp   fn  \
# 1442  0.599388  0.593185      0.0  196  1542  51  211
# 1423  0.580938  0.565220      0.0  192  1531  62  215
# 1407  0.602740  0.561636      0.0  198  1541  52  209
# 1412  0.563253  0.553333      0.0  187  1523  70  220
# 1395  0.571856  0.553171      0.0  191  1523  70  216
#
#                              model sampling_method
# 1442  gradient_boosting_classifier          smoten
# 1423               lgbm_classifier          smoten
# 1407           catboost_classifier          smoten
# 1412                     ada_boost          smoten
# 1395      easy_ensemble_classifier          smoten

# %%
# Sorting using ks_stat
top_ks_stat = df.sort_values(by=['fp'],ascending=True)[:top_n]['k_neighbour']

# Sorting using ks_stat
top_fn = df.sort_values(by=['fn'],ascending=True)[:top_n]['k_neighbour']

best_k = set(top_ks_stat).intersection(set(top_fn))

df = df[df['k_neighbour'].isin(best_k)]

df.sort_values(by=['ks_stat'],ascending=False, inplace=True)

# %%
df.to_csv('./top_class_balancing_methods.csv', header=True, index=False)

# %%
df
# Out:
#                      method k_neighbour  train_accuracy  test_accuracy  \
# 1019      Approach_2_ADASYN        1020        0.674011         0.6595
# 1408  Approach_2_BORDERLINE        1409        0.671115         0.6675
# 109       Approach_2_KMEANS         110        0.774168         0.6565
# 272        Approach_2_SMOTE         273        0.672684         0.6680
# 0       Approach_2_SMOTEENN           1        0.706708         0.5345
# 281       Approach_2_SMOTEN         282        0.797724         0.7020
# 112      Approach_2_SMOTENC         113        0.668838         0.6710
# 115   Approach_2_SMOTETOMEK         116        0.667769         0.6605
# 147     Approach_2_SVMSMOTE         148        0.630691         0.6070
#
#        roc_auc  precision_0  recall_0      f1_0  precision_1  recall_1  \
# 1019  0.675582     0.895147  0.648462  0.752093     0.338061  0.702703
# 1408  0.676946     0.893888  0.661017  0.760014     0.343066  0.692875
# 109   0.574919     0.832111  0.712492  0.767670     0.279874  0.437346
# 272   0.678174     0.894647  0.661017  0.760289     0.343864  0.695332
# 0     0.629126     0.896882  0.469554  0.616399     0.275300  0.788698
# 281   0.563238     0.823072  0.797238  0.809949     0.293217  0.329238
# 112   0.679143     0.894515  0.665411  0.763139     0.346012  0.692875
# 115   0.676210     0.895329  0.649718  0.753001     0.338863  0.702703
# 147   0.627992     0.873265  0.592593  0.706058     0.293798  0.663391
#
#           f1_1   ks_stat  p_value   tp    tn   fp   fn
# 1019  0.456504  0.358090  0.00000  286  1033  560  121
# 1408  0.458910  0.358360  0.00000  282  1053  540  125
# 109   0.341323  0.171993  0.00000  178  1135  458  229
# 272   0.460163  0.371381  0.00000  283  1053  540  124
# 0     0.408137  0.305757  0.00000  321   748  845   86
# 281   0.310185  0.128359  0.00004  134  1270  323  273
# 112   0.461538  0.368350  0.00000  282  1060  533  125
# 115   0.457234  0.357408  0.00000  286  1035  558  121
# 147   0.407240  0.261997  0.00000  270   944  649  137

# %%
methods_ = ['smote', 'adasyn', 'borderline_smote', 'kmeans_smote', 'smoten' , 'svmsmote', 'smoteenn', 'smotetomek']
k_values = [273, 1020, 1409, 110, 282, 148, 1, 116]
# Out:
# 2000

# %%
df
# Out:
#                      method k_neighbour  train_accuracy  test_accuracy  \
# 1234      Approach_1_SMOTEN        1235        0.858477       0.857815
# 1139      Approach_1_SMOTEN        1140        0.858713       0.858757
# 1133      Approach_1_SMOTEN        1134        0.858163       0.859071
# 476       Approach_1_KMEANS         477        0.772998       0.780603
# 460       Approach_1_KMEANS         461        0.774882       0.781230
# 442       Approach_1_KMEANS         443        0.776060       0.778092
# 147     Approach_1_SMOTEENN         148        0.749604       0.772512
# 110     Approach_1_SMOTEENN         111        0.726061       0.770598
# 216     Approach_1_SMOTEENN         217        0.728477       0.764901
# 271   Approach_1_SMOTETOMEK         272        0.748938       0.752336
# 1162  Approach_1_SMOTETOMEK        1163        0.761574       0.754209
# 442   Approach_1_SMOTETOMEK         443        0.750507       0.748186
# 417        Approach_1_SMOTE         418        0.750078       0.750785
# 1761  Approach_1_BORDERLINE        1762        0.744662       0.744821
# 657   Approach_1_BORDERLINE         658        0.748352       0.746390
# 937        Approach_1_SMOTE         938        0.751648       0.744821
# 1071  Approach_1_BORDERLINE        1072        0.751334       0.743252
# 431        Approach_1_SMOTE         432        0.745290       0.745135
# 5        Approach_1_SMOTENC           6        0.745133       0.741682
# 1804      Approach_1_ADASYN        1805        0.751241       0.739373
# 1622      Approach_1_ADASYN        1623        0.749612       0.738442
# 1819      Approach_1_ADASYN        1820        0.750854       0.739684
# 1173    Approach_1_SVMSMOTE        1174        0.729356       0.713748
# 186       Approach_2_ADASYN         187        0.671249       0.664000
# 272        Approach_2_SMOTE         273        0.672684       0.668000
# 143      Approach_2_SMOTENC         144        0.672292       0.672500
# 29       Approach_2_SMOTENC          30        0.672606       0.672500
# 112      Approach_2_SMOTENC         113        0.668838       0.671000
# 77       Approach_1_SMOTENC          78        0.677002       0.678280
# 1545  Approach_2_BORDERLINE        1546        0.675824       0.668500
# 1375  Approach_2_BORDERLINE        1376        0.676923       0.669500
# 1408  Approach_2_BORDERLINE        1409        0.671115       0.667500
# 1019      Approach_2_ADASYN        1020        0.674011       0.659500
# 1108       Approach_2_SMOTE        1109        0.670958       0.669000
# 1593  Approach_2_SMOTETOMEK        1594        0.677593       0.650500
# 1115      Approach_2_ADASYN        1116        0.672537       0.658500
# 115   Approach_2_SMOTETOMEK         116        0.667769       0.660500
# 1202       Approach_2_SMOTE        1203        0.674333       0.667500
# 1603  Approach_2_SMOTETOMEK        1604        0.672532       0.643500
# 1665    Approach_1_SVMSMOTE        1666        0.669309       0.666039
# 78       Approach_1_SMOTENC          79        0.670879       0.664783
# 1339    Approach_1_SVMSMOTE        1340        0.659890       0.661331
# 0       Approach_2_SMOTEENN           1        0.706708       0.534500
# 1551    Approach_2_SMOTEENN        1552        0.724754       0.534500
# 1617    Approach_2_SMOTEENN        1618        0.700087       0.534500
# 136     Approach_2_SVMSMOTE         137        0.638069       0.609000
# 147     Approach_2_SVMSMOTE         148        0.630691       0.607000
# 146     Approach_2_SVMSMOTE         147        0.632732       0.607000
# 105       Approach_2_KMEANS         106        0.772677       0.654500
# 109       Approach_2_KMEANS         110        0.774168       0.656500
# 44        Approach_2_KMEANS          45        0.772599       0.657000
# 289       Approach_2_SMOTEN         290        0.797959       0.701500
# 281       Approach_2_SMOTEN         282        0.797724       0.702000
# 284       Approach_2_SMOTEN         285        0.797881       0.702000
#
#        roc_auc  precision_0  recall_0      f1_0  precision_1  recall_1  \
# 1234  0.857815     0.830243  0.899561  0.863513     0.890411  0.816070
# 1139  0.858757     0.830921  0.900816  0.864458     0.891707  0.816698
# 1133  0.859071     0.830636  0.902072  0.864881     0.892857  0.816070
# 476   0.780603     0.807428  0.736974  0.770594     0.758083  0.824231
# 460   0.781230     0.808116  0.737602  0.771250     0.758661  0.824859
# 442   0.778092     0.806787  0.731325  0.767204     0.754305  0.824859
